# %%
### Document Data Structure
### page_content and metadata   

from langchain_core.documents import Document
from langchain_community.document_loaders import TextLoader

# %%
##Text Loaders

loader = TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python is a popular, high-level computer programming language. It is free, open-source, and known for clean, easy-to-read code that looks like regular English. Created by Guido van Rossum and released in 1991, its name honors the British comedy group Monty Python.\n\nKey Features\nSimple: Uses clear words and spaces so it is easy to learn.\nVersatile: Works for small scripts or huge software projects.\nInterpreted: Runs code line-by-line without a heavy setup step.\nCross-Platform: Works on Windows, Mac, and Linux.\n\nCommon Uses\nArtificial Intelligence: Powers machine learning, data science, and smart AI tools.\nWeb Development: Builds the back end of websites and apps.\nAutomation: Handles boring, repetitive computer tasks automatically.')]

# %%
## Directory Loader
# the same can be done with PDFS using PyMuPDFLoader in the loader_cls
# to find more types of loaders search up LangChain
from langchain_community.document_loaders import DirectoryLoader

dir_loader = DirectoryLoader(
    "../data/text_files", 
    glob="**/*.txt",
    loader_cls=TextLoader,
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=False
)

directory=dir_loader.load()
print(directory)
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that lets computers learn from data and improve tasks over time without being explicitly programmed. Instead of hard-coded rules, models find patterns to make predictions\n\nMain Types of Machine Learning\nSupervised Learning: Uses labeled data and known answers to train models. Examples include regression (predicting numbers) and classification (sorting items).\nUnsupervised Learning: Finds hidden structures or groups in unlabeled data. Examples include customer segmentation and clustering.\nReinforcement Learning: Trains agents through trial, error, rewards, and penalties.\nDeep Learning: Uses multi-layer neural networks for complex tasks like image and speech recognition.'), Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python is a popular, high-level computer programming language. It is free, open-source, and known for clean, easy-to-read code that looks like regular English. Created by Guido van Rossum and released in 1991, its name honors the British comedy group Monty Python.\n\nKey Features\nSimple: Uses clear words and spaces so it is easy to learn.\nVersatile: Works for small scripts or huge software projects.\nInterpreted: Runs code line-by-line without a heavy setup step.\nCross-Platform: Works on Windows, Mac, and Linux.\n\nCommon Uses\nArtificial Intelligence: Powers machine learning, data science, and smart AI tools.\nWeb Development: Builds the back end of websites and apps.\nAutomation: Handles boring, repetitive computer tasks automatically.')]
